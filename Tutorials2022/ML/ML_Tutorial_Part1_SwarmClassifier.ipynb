# %% [markdown]
# # Machine Learning (ML)
#
# ## Part I: Unsupervised Classification, Gaussian Mixture Model and K-Means clustering
#
# <img src="clustering_algos.png" width=900/>
#
# ### Estimated Time: 45 mins

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

from IPython import display
import time

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

# %matplotlib inline

# %%
swarm=xr.open_dataset('swarm.nc') #load the saved data from the swarming model simulation
#xr.Dataset.close(swarm)

# %%
def plot_state(X,Y,theta,colors):   

    U=np.cos(theta)
    V=np.sin(theta)
    
    plt.scatter(X,Y,30,c=colors,alpha=0.5)
    plt.quiver(X,Y,U,V,colors, scale=30)
    plt.xlim((-1,1)); plt.ylim((-1,1))

# %%
j=500;
fig = plt.figure(figsize=(6,6))
plot_state(swarm.x[:,j],swarm.y[:,j],swarm.th[:,j],swarm.colors)
plt.title('Clusters or swarms are evident',fontsize=14);

# %% [markdown]
# # Clustering
#
# Cluster analysis or clustering is the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters). It is a main task of exploratory data analysis, and a common technique for statistical data analysis, used in many fields, including pattern recognition, image analysis, information retrieval, bioinformatics, data compression, computer graphics and machine learning. https://en.wikipedia.org/wiki/Cluster_analysis

# %% [markdown]
# ## Gaussian Mixture Model
#
# A Gaussian mixture model is a probabilistic model that assumes all the data points are generated from a mixture of a finite number of Gaussian distributions with unknown parameters. https://scikit-learn.org/stable/modules/mixture.html

# %%
j=500; #choose some time snapshot

features=np.stack((swarm.x[:,j],
              swarm.y[:,j],
              np.cos(swarm.th[:,j]),
              np.sin(swarm.th[:,j])),
              axis=1);

# %%
K=30 # number of clusters

gmm = GaussianMixture(n_components=K)
labels_gmm=gmm.fit_predict(features)
x_mean,y_mean=gmm.means_[:,0],gmm.means_[:,1]

fig = plt.figure(figsize=(10,10))
plot_state(swarm.x[:,j],swarm.y[:,j],swarm.th[:,j],labels_gmm)
plt.title('Gaussian Mixture Model clastering')
for k in range(K):
    plt.plot(x_mean[k],y_mean[k],'rs',markersize=6)
    plt.annotate(str(k), (x_mean[k],y_mean[k]), fontsize=20)

# %% [markdown]
# ## Bayesian information criterion (BIC)
#
# In statistics, the Bayesian information criterion (BIC) or Schwarz information criterion (also SIC, SBC, SBIC) is a criterion for model selection among a finite set of models; models with lower BIC are generally preferred. It is based, in part, on the likelihood function and it is closely related to the Akaike information criterion (AIC).
#
# When fitting models, it is possible to increase the likelihood by adding parameters, but doing so may result in overfitting. Both BIC and AIC attempt to resolve this problem by introducing a penalty term for the number of parameters in the model. https://en.wikipedia.org/wiki/Bayesian_information_criterion

# %%
BIC=np.array([]);
for K in range(1,50):
    gmm = GaussianMixture(n_components=K)
    gmm.fit_predict(features)
    bic=gmm.bic(features)
    BIC=np.append(BIC,bic)

plt.plot(BIC); 
plt.xlabel('Number of classes'); 
plt.ylabel('Bayesian information criterion (BIC)')
# Out:
# Text(0, 0.5, 'Bayesian information criterion (BIC)')

# %%
K=15 #number of classes to use

# %% [markdown]
# ## K-means clustering
#
# K-means clustering is a method of vector quantization, originally from signal processing, that aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean (cluster centers or cluster centroid), serving as a prototype of the cluster. This results in a partitioning of the data space into Voronoi cells. k-means clustering minimizes within-cluster variances (squared Euclidean distances). https://en.wikipedia.org/wiki/K-means_clustering

# %% [markdown]
# ## In class exercise \#1: K-means clustering
#
# - Follow an example of Gaussian Mixture Model above to cluster the data using the k-means algorithm. The sklearn documentation for k-means is here https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
#
# - Make the same plot as above that denotes the clusters with colors and plots the centers of clusters with their cluster numbers. Compare the clustering by GMM with k-means: which is better?

# %%
#your code goes here

# %%
# Out:
# Text(0.5, 1.0, 'k-means')

# %%
K=20

fig = plt.figure(figsize=(10,10))

ini=True

for j in np.arange(400,500,5):
        
    features=np.stack((swarm.x[:,j],
              swarm.y[:,j],
              np.cos(swarm.th[:,j]),
              np.sin(swarm.th[:,j])),
              axis=1);
    
    if ini: kmeans = KMeans(n_clusters=K).fit(features); ini=False
    else:   kmeans = KMeans(n_clusters=K, n_init=1,init=kmeans.cluster_centers_).fit(features)
    
    x_mean, y_mean =kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1]
    
    labels=kmeans.labels_


    #plotting results
    display.display(plt.gcf()); plt.clf()
    
    plot_state(swarm.x[:,j],swarm.y[:,j],swarm.th[:,j],labels)   
    
    for k in range(K):
        plt.plot(x_mean[k],y_mean[k],'rs',markersize=6)
        plt.annotate(str(k), (x_mean[k],y_mean[k]), fontsize=20)
        
    display.clear_output(wait=True)
    
    time.sleep(0.01)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e907e872ad9e> in <module>
#      24     display.display(plt.gcf()); plt.clf()
#      25
# ---> 26     plot_state(swarm.x[:,j],swarm.y[:,j],swarm.th[:,j],labels)
#      27
#      28     for k in range(K):
#
# <ipython-input-5-284f02384493> in plot_state(X, Y, theta, colors)
#       4     V=np.sin(theta)
#       5
# ----> 6     plt.scatter(X,Y,30,c=colors,alpha=0.5)
#       7     plt.quiver(X,Y,U,V,colors, scale=30)
#       8     plt.xlim((-1,1)); plt.ylim((-1,1))
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#    2260 @_copy_docstring_and_deprecators(Figure.gca)
#    2261 def gca(**kwargs):
# -> 2262     return gcf().gca(**kwargs)
#    2263
#    2264
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1513                 "plt.subplot().")
#    1514         if self._axstack.empty():
# -> 1515             return self.add_subplot(1, 1, 1, **kwargs)
#    1516         else:
#    1517             return self._axstack()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     454                 "parameter will become keyword-only %(removal)s.",
#     455                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456         return func(*args, **kwargs)
#     457
#     458     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     630
#     631         self._rasterization_zorder = None
# --> 632         self.cla()
#     633
#     634         # funcs used to format x and y - fall back on major formatters
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1247         self.containers = []
#    1248
# -> 1249         self.grid(False)  # Disable grid on init to use rcParameter
#    1250         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1251                   axis=mpl.rcParams['axes.grid.axis'])
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3224         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3225         if axis in ['x', 'both']:
# -> 3226             self.xaxis.grid(visible, which=which, **kwargs)
#    3227         if axis in ['y', 'both']:
#    3228             self.yaxis.grid(visible, which=which, **kwargs)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     297                 f"for the old name will be dropped %(removal)s.")
#     298             kwargs[new] = kwargs.pop(old)
# --> 299         return func(*args, **kwargs)
#     300
#     301     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1432             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                                 if visible is None else visible)
# -> 1434             self.set_tick_params(which='major', **gridkw)
#    1435         self.stale = True
#    1436
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     871             if which in ['major', 'both']:
#     872                 self._major_tick_kw.update(kwtrans)
# --> 873                 for tick in self.majorTicks:
#     874                     tick._apply_params(**kwtrans)
#     875             if which in ['minor', 'both']:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     591                 instance.majorTicks = []
#     592                 tick = instance._get_tick(major=True)
# --> 593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#     595             else:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     590             if self._major:
#     591                 instance.majorTicks = []
# --> 592                 tick = instance._get_tick(major=True)
#     593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2055         else:
#    2056             tick_kw = self._minor_tick_kw
# -> 2057         return XTick(self.axes, 0, major=major, **tick_kw)
#    2058
#    2059     def set_label_position(self, position):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     413
#     414     def __init__(self, *args, **kwargs):
# --> 415         super().__init__(*args, **kwargs)
#     416         # x in data coords, y in axes coords
#     417         ax = self.axes
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#      83         size is the tick size in points
#      84         """
# ---> 85         super().__init__()
#      86
#      87         if gridOn is None:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in __init__(self)
#     163         self._label = ''
#     164         self._picker = None
# --> 165         self._rasterized = False
#     166         self._agg_filter = None
#     167         # Normally, artist classes need to be queried for mouseover info if and
#
# KeyboardInterrupt:
